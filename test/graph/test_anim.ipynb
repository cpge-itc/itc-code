# %% [markdown]
# # Tests and examples for graph.anim

# %%
# %load_ext autoreload
# %autoreload 3
import cpge.graph
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /home/qfortier/cours/info/itc/itc-code/test/graph/test_anim.ipynb Cell 2' in <cell line: 3>()
#       <a href='vscode-notebook-cell:/home/qfortier/cours/info/itc/itc-code/test/graph/test_anim.ipynb#ch0000001?line=0'>1</a> get_ipython().run_line_magic('load_ext', 'autoreload')
#       <a href='vscode-notebook-cell:/home/qfortier/cours/info/itc/itc-code/test/graph/test_anim.ipynb#ch0000001?line=1'>2</a> get_ipython().run_line_magic('autoreload', '3')
# ----> <a href='vscode-notebook-cell:/home/qfortier/cours/info/itc/itc-code/test/graph/test_anim.ipynb#ch0000001?line=2'>3</a> import cpge.graph
#
# ModuleNotFoundError: No module named 'cpge.graph'

# %% [markdown]
# ## DFS

# %%
G = cpge.graph.random_matrix(n=8, p=0.35, directed=False, weighted=False)
cpge.graph.anim_dfs(G)
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
# ...

# %% [markdown]
# ## BFS

# %%
cpge.graph.anim_bfs(G)
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
# ...

# %% [markdown]
# ## Dijkstra

# %%
G = cpge.graph.random_matrix(directed=False, weighted=True)
G
# Out:
# [[inf, inf, inf, inf, 5, inf, inf, 8],
#  [inf, inf, inf, inf, 3, inf, inf, inf],
#  [inf, inf, inf, 7, inf, 3, inf, 2],
#  [inf, inf, 7, inf, 1, 7, 9, 4],
#  [5, 3, inf, 1, inf, 1, 2, inf],
#  [inf, inf, 3, 7, 1, inf, 8, inf],
#  [inf, inf, inf, 9, 2, 8, inf, inf],
#  [8, inf, 2, 4, inf, inf, inf, inf]]

# %%
cpge.graph.anim_dijkstra(G, 0)
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
# ...
